# %%
import librosa

x , sr = librosa.load("tmp.mp3", sr=8000)
print(x.shape, sr)
# Out:
# (30144,) 8000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
import numpy as np

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveshow(np.diff(x), sr=sr)

# %%
x / max(x)
# Out:
# array([0.5572384 , 0.8642451 , 0.8648835 , 0.6610319 , 0.8583063 ,
#        0.7018626 , 0.4660584 , 0.86183625, 1.        , 0.83144957,
#        0.9225353 , 0.55261177, 0.        , 0.205186  , 0.5569429 ,
#        0.5723406 ], dtype=float32)
